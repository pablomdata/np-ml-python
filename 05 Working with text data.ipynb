# %%
import pandas as pd

# %%
df = pd.read_excel('./data/wos.xlsx')

# %%
df.head()
# Out:
#    Y1  Y2    Y    Domain                     area  \
# 0   0  12   12       CS    Symbolic computation
# 1   5   2   74  Medical     Alzheimer's Disease
# 2   4   7   68    Civil          Green Building
# 3   1  10   26      ECE          Electric motor
# 4   5  43  115  Medical     Parkinson's Disease
#
#                                             keywords  \
# 0   (2+1)-dimensional non-linear optical waves; e...
# 1   Aging; Tau; Amyloid; PET; Alzheimer's disease...
# 2   LED lighting system; PV system; Distributed l...
# 3   NdFeB magnets; Electric motor; Electric vehic...
# 4   Parkinson's disease; dyskinesia; adenosine A(...
#
#                                             Abstract
# 0  (2 + 1)-dimensional non-linear optical waves t...
# 1  (beta-amyloid (A beta) and tau pathology becom...
# 2  (D)ecreasing of energy consumption and environ...
# 3  (Hybrid) electric vehicles are assumed to play...
# 4  (L)-3,4-Dihydroxyphenylalanine ((L)-DOPA) rema...

# %% [markdown]
# **Goal:** Predict domain of a scientific article using the abstract information.

# %%
set(df['Domain'])
# Out:
# {'CS ', 'Civil ', 'ECE ', 'MAE ', 'Medical ', 'Psychology  ', 'biochemistry '}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer

# %%
vec = CountVectorizer(stop_words='english') # can pass a list of stop words instead (which you can find online)

# %%
vec.fit(df['Abstract'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vec.vocabulary_
# Out:
# {'dimensional': 35622,
#  'non': 78779,
#  'linear': 66174,
#  'optical': 82286,
#  'waves': 121975,
#  'coherently': 27018,
#  'excited': 43064,
#  'resonant': 97851,
#  'medium': 70129,
#  'doped': 37289,
#  'erbium': 41871,
#  'atoms': 15302,
#  'described': 34287,
#  'schrodinger': 102412,
#  'equation': 41764,
#  'coupled': 30048,
#  'self': 103240,
#  'induced': 58670,
#  'transparency': 115645,
#  'equations': 41768,
#  'hirota': 53971,
#  'method': 71056,
#  'symbolic': 111003,
#  'computation': 27888,
#  'forms': 46661,
#  'soliton': 106528,
#  'solutions': 106558,
#  'obtained': 81050,
#  'asymptotic': 15093,
#  'analysis': 12134,
#  'conducted': 28492,
#  'suggests': 109942,
#  'interaction': 59746,
#  'solitons': 106530,
#  'elastic': 39767,
#  'bright': 20582,
#  'fields': 45179,
#  'dark': 32521,
#  'ones': 81922,
#  'field': 45173,
#  'electric': 39842,
#  'polarization': 89540,
#  'population': 90119,
#  'inversion': 60691,
#  'profile': 92127,
#  'dopant': 37284,
#  'head': 52717,
#  'bidirectional': 18308,
#  'overtaking': 83573,
#  'unidirectional': 118390,
#  'seen': 103109,
#  'influence': 58934,
#  'averaged': 15955,
#  'natural': 76733,
#  'frequency': 47092,
#  'studied': 109138,
#  'affect': 10003,
#  'velocities': 120220,
#  'amplitudes': 11978,
#  'increase': 58434,
#  'decreasing': 33238,
#  'decrease': 33232,
#  'increasing': 58443,
#  'peak': 85766,
#  'turns': 117023,
#  'type': 117187,
#  'changes': 24559,
#  'results': 98042,
#  'paper': 84515,
#  'potential': 90603,
#  'applications': 13644,
#  'design': 34342,
#  'communication': 27550,
#  'systems': 111317,
#  'produce': 92075,
#  'simultaneously': 105183,
#  'beta': 18033,
#  'amyloid': 12037,
#  'tau': 111985,
#  'pathology': 85234,
#  'increasingly': 58444,
#  'prevalent': 91697,
#  'age': 10192,
#  'spatial': 106979,
#  'relationship': 97089,
#  'pathologies': 85230,
#  'remains': 97211,
#  'unknown': 118555,
#  'examined': 42980,
#  'local': 66738,
#  'region': 96813,
#  'different': 35351,
#  'associations': 14952,
#  'aggregated': 10257,
#  'proteins': 92693,
#  '46': 5171,
#  'normal': 79782,
#  'older': 81621,
#  'adults': 9694,
#  'using': 119368,
#  '18': 2179,
#  'av': 15917,
#  '1451': 1586,
#  '11': 932,
#  'pib': 88129,
#  'positron': 90264,
#  'emission': 40389,
#  'tomography': 114747,
#  'pet': 86840,
#  'magnetic': 68259,
#  'resonance': 97849,
#  'imaging': 57536,
#  'mri': 74626,
#  'images': 57525,
#  'voxelwise': 121374,
#  'analyses': 12132,
#  'showed': 104610,
#  'tracer': 115186,
#  'largely': 64719,
#  'temporal': 112581,
#  'lobes': 66724,
#  'means': 69883,
#  'clustering': 26459,
#  'revealed': 98579,
#  'driven': 37723,
#  'regions': 96819,
#  'low': 67096,
#  'retention': 98389,
#  'followed': 46381,
#  'brain': 20315,
#  'partial': 84957,
#  'correlational': 29702,
#  'calculated': 21926,
#  'participant': 84963,
#  'mean': 69868,
#  'uptake': 119110,
#  'values': 119772,
#  '87': 7301,
#  'roi': 99641,
#  'pairwise': 84226,
#  'demonstrated': 33823,
#  'positive': 90251,
#  'importantly': 58071,
#  'strong': 109067,
#  'correlations': 29703,
#  'controlling': 29259,
#  'sex': 103981,
#  'global': 49692,
#  'gray': 50847,
#  'matter': 69376,
#  'fraction': 46909,
#  '01': 184,
#  'identified': 56926,
#  'multiple': 75301,
#  'association': 14951,
#  'cortex': 29759,
#  'cortical': 29762,
#  'rois': 99644,
#  'frequent': 47094,
#  'weaker': 122066,
#  'regional': 96814,
#  'frontoparietal': 47248,
#  'particularly': 85008,
#  'lobe': 66719,
#  'strongly': 109071,
#  'predicted': 91183,
#  'nb': 76801,
#  'locations': 66773,
#  'data': 32583,
#  'indicate': 58551,
#  'significant': 104944,
#  'cognitively': 26992,
#  'elderly': 39809,
#  'increased': 58436,
#  'correlating': 29700,
#  'accumulation': 8663,
#  'does': 37127,
#  'appear': 13600,
#  'specific': 107066,
#  'location': 66770,
#  'suggesting': 109935,
#  'vulnerability': 121540,
#  'regardless': 96778,
#  'ap': 13366,
#  'accumulates': 8661,
#  'ecreasing': 39079,
#  'energy': 40939,
#  'consumption': 29013,
#  'environmentally': 41349,
#  'friendly': 47156,
#  'resources': 97877,
#  'issues': 61580,
#  'foreground': 46524,
#  'nowadays': 80013,
#  'consumed': 29003,
#  'illumination': 57461,
#  'high': 53802,
#  'long': 66916,
#  'lasting': 64778,
#  'led': 65226,
#  'light': 65990,
#  'emitting': 40402,
#  'diode': 35787,
#  'technology': 112356,
#  'gets': 49170,
#  'prominent': 92320,
#  'reseacrh': 97714,
#  'regarding': 96776,
#  'use': 119324,
#  'photovoltaic': 87885,
#  'sytems': 111330,
#  'meeting': 70166,
#  'demand': 33729,
#  'housing': 54828,
#  'industry': 58709,
#  'need': 77175,
#  'research': 97716,
#  'regards': 96779,
#  'integration': 59662,
#  'efficiency': 39408,
#  'study': 109146,
#  'environments': 41352,
#  'lighting': 66000,
#  'levels': 65622,
#  'daylight': 32673,
#  'factor': 43966,
#  'proposed': 92501,
#  'cost': 29862,
#  'pv': 93909,
#  'photovoltaics': 87886,
#  'based': 17162,
#  'distributed': 36646,
#  'sensor': 103510,
#  'smart': 105896,
#  'illuminating': 57460,
#  'acquired': 8948,
#  '72': 6719,
#  '075': 519,
#  'saving': 101935,
#  'comparison': 27634,
#  'conventional': 29292,
#  '2017': 2752,
#  'elsevier': 40184,
#  'rights': 99158,
#  'reserved': 97755,
#  'hybrid': 55573,
#  'vehicles': 120191,
#  'assumed': 14970,
#  'play': 88883,
#  'major': 68404,
#  'role': 99653,
#  'future': 47692,
#  'mobility': 73459,
#  'concepts': 27981,
#  'sales': 101466,
#  'numbers': 80470,
#  'little': 66485,
#  'emphasis': 40455,
#  'laid': 64466,
#  'recycling': 96449,
#  'key': 63200,
#  'components': 27787,
#  'power': 90681,
#  'electronics': 39962,
#  'motors': 74366,
#  'permanent': 86578,
#  'magnet': 68258,
#  'synchronous': 111126,
#  'contain': 29033,
#  'considerable': 28847,
#  'amounts': 11908,
#  'rare': 95507,
#  'earth': 38701,
#  'elements': 40044,
#  'recovered': 96363,
#  'routes': 99887,
#  'large': 64718,
#  'economic': 39009,
#  'environmental': 41345,
#  'strategic': 108870,
#  'advantages': 9713,
#  'industrial': 58698,
#  'magnets': 68314,
#  'available': 15923,
#  'western': 122313,
#  'countries': 30036,
#  'moment': 73767,
#  'essential': 42262,
#  'steps': 108475,
#  'dismantling': 36336,
#  'extraction': 43644,
#  'rotors': 99847,
#  'published': 93562,
#  'presents': 91559,
#  'discusses': 36189,
#  'approaches': 13705,
#  'ndfeb': 77031,
#  'stem': 108433,
#  'german': 49107,
#  'project': 92242,
#  'metals': 70915,
#  'drive': 37719,
#  'dihydroxyphenylalanine': 35541,
#  'dopa': 37277,
#  'primary': 91772,
#  'pharmacological': 87209,
#  'agent': 10216,
#  'symptomatic': 111059,
#  'treatment': 115834,
#  'parkinson': 84893,
#  'disease': 36230,
#  'pd': 85621,
#  'development': 34689,
#  'dyskinesia': 38411,
#  'lid': 65907,
#  'limits': 66116,
#  'term': 112753,
#  'patients': 85267,
#  'reported': 97547,
#  'adenosine': 9373,
#  '2a': 3752,
#  'receptor': 96149,
#  'antagonists': 12786,
#  'prevented': 91708,
#  'animal': 12522,
#  'model': 73510,
#  'mechanism': 69982,
#  'blockade': 19436,
#  'alleviates': 11200,
#  'symptoms': 111069,
#  'fully': 47498,
#  'clarified': 26020,
#  'determined': 34601,
#  'knock': 63698,
#  'ko': 63739,
#  'gene': 48709,
#  'explored': 43465,
#  'possible': 90284,
#  'underlying': 118084,
#  'mechanisms': 69986,
#  'implicated': 58048,
#  'mouse': 74407,
#  'mice': 71758,
#  'unilaterally': 118421,
#  'injected': 59179,
#  'striatum': 108989,
#  'hydroxydopamine': 55829,
#  'ohda': 81531,
#  'order': 82426,
#  'damage': 32403,
#  'dopamine': 37281,
#  'neurons': 77720,
#  'lesioned': 65485,
#  'daily': 32371,
#  '21': 2907,
#  'days': 32678,
#  'abnormal': 8289,
#  'involuntary': 60756,
#  'movements': 74426,
#  'aims': 10572,
#  'evaluated': 42778,
#  '13': 1341,
#  'administration': 9529,
#  'real': 95927,
#  'time': 114158,
#  'polymerase': 89835,
#  'chain': 24480,
#  'reaction': 95867,
#  'immunohistochemistry': 57797,
#  'glutamic': 49910,
#  'acid': 8838,
#  'decarboxylase': 33038,
#  'gad': 47919,
#  '65': 6346,
#  'gad67': 47922,
#  'performed': 86362,
#  'effective': 39373,
#  'reducing': 96539,
#  'aim': 10537,
#  'scores': 102601,
#  'accompanied': 8601,
#  'striatal': 108981,
#  'gad65': 47921,
#  'involved': 60761,
#  'alleviation': 11202,
#  'expression': 43526,
#  'objective': 80805,
#  'classification': 26049,
#  'accuracy': 8670,
#  'tea': 112277,
#  'category': 23132,
#  'identification': 56924,
#  'tci': 112175,
#  'novel': 79994,
#  'approach': 13701,
#  'methods': 71103,
#  'extracted': 43642,
#  '64': 6317,
#  'color': 27306,
#  'histogram': 54043,
#  'obtain': 81047,
#  'information': 58971,
#  '16': 1880,
#  'wavelet': 121967,
#  'packet': 84109,
#  'entropy': 41306,
#  'texture': 113082,
#  '80': 7060,
#  'features': 44570,
#  'principal': 91808,
#  'component': 27784,
#  'harnessed': 52306,
#  'reduced': 96530,
#  'used': 119329,
#  'input': 59332,
#  'generalized': 48752,
#  'eigenvalue': 39656,
#  'proximal': 92868,
#  'support': 110452,
#  'vector': 120141,
#  'machine': 67999,
#  'gepsvm': 49078,
#  'winner': 122685,
#  'takes': 111661,
#  'wta': 123232,
#  'handle': 52122,
#  'multiclass': 75096,
#  'problem': 91950,
#  'kernels': 63137,
#  'tested': 112867,
#  'kernel': 63134,
#  'radial': 95093,
#  'basis': 17208,
#  'function': 47521,
#  'rbf': 95685,
#  'repetitions': 97474,
#  '10': 632,
#  'fold': 46343,
#  'stratified': 108878,
#  'cross': 30708,
#  'validation': 119726,
#  'technique': 112339,
#  'estimate': 42319,
#  'sample': 101591,
#  'errors': 42019,
#  'named': 76246,
#  'result': 98023,
#  'pca': 85489,
#  'merely': 70610,
#  'explaining': 43421,
#  '99': 7791,
#  '90': 7474,
#  'total': 114967,
#  'variance': 119874,
#  'recall': 96097,
#  'rate': 95566,
#  'achieved': 8808,
#  'highest': 53809,
#  'overall': 83317,
#  '97': 7721,
#  'conclusion': 28031,
#  'higher': 53807,
#  'state': 108262,
#  'art': 14394,
#  'algorithms': 11043,
#  'propagation': 92409,
#  'neural': 77528,
#  'network': 77509,
#  'genetic': 48793,
#  'discriminant': 36166,
#  'fitness': 45575,
#  'scaling': 102104,
#  'chaotic': 24594,
#  'artificial': 14487,
#  'bee': 17613,
#  'colony': 27304,
#  'ecent': 38884,
#  'advances': 9707,
#  'deep': 33294,
#  'stimulators': 108653,
#  'interfaces': 59892,
#  'greatly': 50876,
#  'expanded': 43319,
#  'possibilities': 90282,
#  'neuroprosthetics': 77760,
#  'neuromodulation': 77702,
#  'neuroengineering': 77625,
#  'nanotechnology': 76530,
#  'molecular': 73711,
#  'biology': 18757,
#  'material': 69278,
#  'sciences': 102445,
#  'address': 9317,
#  'fundamental': 47550,
#  'questions': 94735,
#  'neuroscience': 77794,
#  'new': 77900,
#  'powerful': 90687,
#  'ways': 121994,
#  'apply': 13655,
#  'technologies': 112353,
#  'range': 95432,
#  'augmenting': 15596,
#  'restoring': 97986,
#  'modalities': 73501,
#  'treat': 115825,
#  'neuropsychiatric': 77767,
#  'disorders': 36363,
#  'recent': 96135,
#  'developments': 34692,
#  'offer': 81416,
#  'clinical': 26259,
#  'benefits': 17834,
#  'variety': 119908,
#  'current': 31490,
#  'describing': 34290,
#  'limitations': 66104,
#  'shape': 104246,
#  'psychiatry': 93281,
#  'medicine': 70095,
#  'safety': 101357,
#  'ethical': 42436,
#  'implications': 58052,
#  'discussed': 36188,
#  'concept': 27975,
#  'software': 106439,
#  'defined': 33402,
#  'radio': 95123,
#  'flexible': 45828,
#  'rf': 98749,
#  'end': 40692,
#  'architecture': 14012,
#  'application': 13643,
#  'examples': 42992,
#  'explained': 43420,
#  'scenario': 102225,
#  'operation': 82141,
#  'maritime': 69017,
#  'bands': 16927,
#  'known': 63724,
#  'service': 103819,
#  'automatic': 15810,
#  'ais': 10683,
#  'captured': 22452,
#  'dlr': 36869,
#  'mission': 73055,
#  'aisat': 10685,
#  'chosen': 25356,
#  'example': 42990,
#  'embedded': 40274,
#  'solution': 106557,
#  'sdr': 102843,
#  'platform': 88857,
#  'presented': 91550,
#  'request': 97658,
#  'performance': 86351,
#  'services': 103825,
#  'like': 66042,
#  'enhanced': 40999,
#  'international': 60030,
#  'marine': 69006,
#  'aids': 10512,
#  'navigation': 76777,
#  'lighthouse': 65999,
#  'authorities': 15707,
#  'iala': 56576,
#  'vhf': 120589,
#  'exchange': 43040,
#  'vdes': 120109,
#  'shall': 104211,
#  'implement': 58029,
#  'dedicated': 33265,
#  'satellite': 101847,
#  'link': 66229,
#  'describes': 34289,
#  'demonstration': 33826,
#  'upcoming': 118996,
#  'develop': 34681,
#  'generalised': 48740,
#  'unsteady': 118862,
#  'plume': 89114,
#  'theory': 113387,
#  'compare': 27625,
#  'direct': 35912,
#  'numerical': 80482,
#  'simulation': 105168,
#  'dns': 37039,
#  'dataset': 32614,
#  'ensemble': 41116,
#  'statistically': 108296,
#  'turbulent': 116985,
#  'plumes': 89115,
#  'theoretical': 113372,
#  'framework': 46963,
#  'generalises': 48741,
#  'previous': 91725,
#  'models': 73530,
#  'exposes': 43496,
#  'aspects': 14807,
#  'physics': 88009,
#  'allows': 11296,
#  'understand': 118147,
#  'structure': 109089,
#  'governing': 50447,
#  'integral': 59650,
#  'depends': 34059,
#  'assumptions': 14975,
#  'makes': 68428,
#  'dependence': 34050,
#  'longitudinal': 66944,
#  'velocity': 120221,
#  'turbulence': 116983,
#  'pressure': 91597,
#  'consequently': 28822,
#  'ill': 57433,
#  'posed': 90229,
#  'scase': 102169,
#  'hewitt': 53539,
#  'fluid': 46047,
#  'mech': 69973,
#  'vol': 121251,
#  '697': 6525,
#  '2012': 2734,
#  'pp': 90721,
#  '455': 5131,
#  '480': 5262,
#  'shown': 104618,
#  'physical': 87997,
#  'assumption': 14974,
#  'reveals': 98582,
#  'degenerate': 33475,
#  'cases': 22937,
#  'comparatively': 27620,
#  'set': 103871,
#  'derived': 34205,
#  'drawing': 37631,
#  'subjected': 109436,
#  'instantaneous': 59488,
#  'step': 108457,
#  'change': 24549,
#  'source': 106779,
#  'buoyancy': 21191,
#  'flux': 46156,
#  'diagnostic': 34967,
#  'capacity': 22350,
#  'investigate': 60710,
#  'properties': 92443,
#  'resulting': 98039,
#  'travelling': 115787,
#  'wave': 121951,
#  'general': 48732,
#  'hyperbolic': 55989,
#  'parabolic': 84567,
#  'limiting': 66113,
#  'case': 22914,
#  'hat': 52394,
#  'classified': 26052,
#  'lazy': 64953,
#  'pure': 93771,
#  'forced': 46488,
#  'according': 8617,
#  'particular': 85002,
#  'invoked': 60750,
#  'close': 26364,
#  'guided': 51396,
#  'observations': 81007,
#  'prognostic': 92180,
#  'relatively': 97094,
#  'simple': 105124,
#  'accurate': 8672,
#  'gaussian': 48389,
#  'analytical': 12145,
#  'straight': 108829,
#  'sided': 104810,
#  'consistent': 28868,
#  'observed': 81011,
#  'ghrelin': 49309,
#  'cells': 23944,
#  'numerous': 80487,
#  'se': 102860,
#  'reports': 97555,
#  'endocrine': 40745,
#  'kinetics': 63451,
#  'corpus': 29678,
#  'human': 55313,
#  'stomach': 108752,
#  'limited': 66107,
#  'examine': 42979,
#  'appearance': 13601,
#  'localization': 66754,
#  'density': 33947,
#  'cell': 23924,
#  'types': 117198,
#  'prenatal': 91406,
#  'early': 38677,
#  'postnatal': 90474,
#  'chromogranin': 25439,
#  'somatostatin': 106601,
#  'glucagon': 49815,
#  'serotonin': 103768,
#  'embryos': 40326,
#  '38': 4513,
#  'fetuses': 44919,
#  'infants': 58797,
#  'secreting': 103001,
#  'week': 122166,
#  'gestation': 49152,
#  'present': 91539,
#  '10th': 919,
#  '11th': 1109,
#  '12th': 1333,
#  'individually': 58630,
#  'clustered': 26457,
#  'glandular': 49556,
#  'base': 17159,
#  'body': 19730,
#  'trimester': 116188,
#  'separately': 103564,
#  'basal': 17143,
#  'central': 24048,
#  'parts': 85045,
#  'glands': 49555,
#  'second': 102973,
#  'trimesters': 116190,
#  'common': 27520,
#  'similar': 105101,
#  'trimestercond': 116189,
#  '34': 4262,
#  '28': 3606,
#  'percentage': 86247,
#  'pregnancy': 91294,
#  'just': 62559,
#  'birth': 19077,
#  'largest': 64722,
#  'number': 80465,
#  'suggest': 109931,
#  'secretory': 103011,
#  'products': 92091,
#  'regulation': 96890,
#  'homeostasis': 54469,
#  'growth': 51107,
#  'differentiation': 35366,
#  'background': 16406,
#  'patterns': 85314,
#  'water': 121887,
#  'tubing': 116821,
#  'related': 97076,
#  'injuries': 59193,
#  'treated': 115828,
#  'emergency': 40348,
#  'departments': 34036,
#  'national': 76700,
#  'electronic': 39959,
#  'injury': 59196,
#  'surveillance': 110619,
#  'weights': 122214,
#  'calculate': 21925,
#  'estimates': 42321,
#  '2010': 2727,
#  '1991': 2475,
#  '2009': 2700,
#  'estimated': 42320,
#  '69': 6506,
#  '471': 5223,
#  'annual': 12661,
#  '250': 3329,
#  '19': 2332,
#  'year': 123795,
#  'period': 86472,
#  '001': 68,
#  'sprains': 107621,
#  'strains': 108843,
#  'accounted': 8625,
#  'portion': 90198,
#  '27': 3518,
#  'frequently': 47099,
#  'injured': 59190,
#  'children': 25013,
#  'adolescents': 9576,
#  '20': 2668,
#  'years': 123802,
#  'likely': 66053,
#  'individuals': 58631,
#  'sustain': 110688,
#  '95': 7645,
#  'ci': 25582,
#  '71': 6686,
#  'commonly': 27527,
#  'impact': 57935,
#  '54': 5716,
#  'conclusions': 28135,
#  'differ': 35342,
#  'needed': 77176,
#  'determine': 34600,
#  'best': 18024,
#  'reduce': 96529,
#  'feature': 44566,
#  'factorixa': 43979,
#  'allosteric': 11277,
#  'transformation': 115496,
#  'enzymatically': 41377,
#  'latent': 64795,
#  'form': 46601,
#  'potent': 90602,
#  'procoagulant': 92027,
#  'small': 105879,
#  'molecules': 73716,
#  'capable': 22336,
#  'partially': 84960,
#  'affecting': 10005,
#  'fixa': 45598,
#  'ethylene': 42513,
#  'glycol': 50032,
#  'ca2': 21682,
#  'weight': 122205,
#  'heparin': 53195,
#  'lmwh': 66640,
#  'modest': 73559,
#  'peptidolytic': 86220,
#  'activity': 9113,
#  'action': 9072,
#  'challenging': 24511,
#  'effects': 39383,
#  'provide': 92827,
#  'hints': 53933,
#  'regulatory': 96896,
#  'forces': 46492,
#  'operational': 82142,
#  'coagulant': 26701,
#  'description': 34293,
#  'great': 50873,
#  'studies': 109140,
#  'crystal': 30965,
#  'structures': 109097,
#  'yielded': 123858,
#  'insights': 59420,
#  'structural': 109085,
#  'effectors': 39382,
#  'paucity': 85322,
#  'correlate': 29697,
#  'given': 49496,
#  'consequences': 28816,
#  'objectives': 80874,
#  'modulators': 73610,
#  'substrate': 109704,
#  'discrimination': 36172,
#  'peptidomics': 86221,
#  'mass': 69204,
#  'spectrometry': 107127,
#  'ms': 74676,
#  'hydrolysis': 55717,
#  'combinatorial': 27387,
#  'chemistry': 24837,
#  'pentapeptide': 86145,
#  'libraries': 65860,
#  'various': 119915,
#  'conditions': 28472,
#  'soluble': 106552,
#  'active': 9097,
#  'enzyme': 41379,
#  'specifically': 107067,
#  'altered': 11444,
#  's3': 101179,
#  'subsite': 109644,
#  'render': 97323,
#  'tolerant': 114684,
#  'chains': 24485,
#  'p3': 83934,
#  'position': 90242,
#  'tolerance': 114681,
#  's2': 101164,
#  'contrast': 29215,
#  's1': 101122,
#  'subsites': 109645,
#  'demonstrate': 33822,
#  'plasticity': 88823,
#  'regulating': 96889,
#  'respect': 97884,
#  'extended': 43562,
#  'sequences': 103628,
#  'providing': 92834,
#  'crucial': 30817,
#  'site': 105385,
#  'modulations': 73608,
#  'capitalized': 22379,
#  'physiologic': 88019,
#  'cofactors': 26962,
#  'drug': 37815,
#  'haemophilia': 51877,
#  'ha': 51746,
#  'caused': 23236,
#  'widespread': 122517,
#  'mutations': 75633,
#  'viii': 120753,
#  'spontaneous': 107538,
#  'mutation': 75629,
#  'roughly': 99860,
#  '40': 4792,
#  'private': 91867,
#  'aimed': 10552,
#  'confirm': 28572,
#  'causing': 23239,
#  'cohort': 27030,
#  'belgian': 17741,
#  '148': 1628,
#  'unrelated': 118764,
#  'families': 44161,
#  'presence': 91533,
#  'intron': 60580,
#  '22': 3023,
#  'southern': 106814,
#  'blotting': 19484,
#  'pcr': 85597,
#  'multiplex': 75303,
#  'ligation': 65985,
#  'dependent': 34054,
#  'probe': 91939,
#  'amplification': 11965,
#  'mlpa': 73256,
#  'assay': 14877,
#  'detect': 34553,
#  'genomic': 48852,
#  'rearrangements': 96004,
#  'detection': 34560,
#  'point': 89484,
#  'dna': 36988,
#  'sequencing': 103629,
#  'predicting': 91184,
#  'causal': 23227,
#  'synonymous': 111190,
#  'strategies': 108873,
#  'family': 44164,
#  'cosegregation': 29812,
#  'evaluation': 42781,
#  'codon': 26914,
#  'phylogenic': 87968,
#  'separated': 103563,
#  'species': 107061,
#  'absence': 8376,
#  'ii': 57248,
#  'bioinformatics': 18729,
#  'analyse': 12126,
#  'functional': 47522,
#  'missense': 73048,
#  'addition': 9305,
#  'inversions': 60692,
#  'deletions': 33634,
#  'duplications': 38148,
#  '67': 6429,
#  '42': 4949,
#  'hamsters': 52083,
#  'database': 32587,
#  '25': 3328,
#  'including': 58353,
#  'null': 80445,
#  'variants': 119878,
#  'rna': 99454,
#  'confirmed': 28580,
#  'effect': 39369,
#  'located': 66766,
#  'splice': 107438,
#  'consensus': 28809,
#  '15': 1686,
#  'causality': 23229,
#  'article': 14468,
#  'evaluate': 42777,
#  'deleterious': 33627,
#  'unreported': 118776,
#  'f8': 43864,
#  'substitutions': 109694,
#  'purpose': 93811,
#  'telomere': 112531,
#  'length': 65385,
#  'macular': 68159,
#  'degeneration': 33479,
#  'amd': 11635,
#  'circulating': 25793,
#  'leucocyte': 65547,
#  'proportion': 92486,
#  'telomeres': 112532,
#  '5kb': 6038,
#  'analysed': 12127,
#  'blood': 19460,
#  'samples': 101599,
#  'taken': 111655,
#  '121': 1145,
#  'exudative': 43763,
#  '83': 7182,
#  'drusen': 37831,
#  '14': 1511,
#  'geographic': 48962,
#  'atrophy': 15379,
#  'controls': 29263,
#  'consisted': 28864,
#  '77': 6882,
#  'matched': 69262,
#  'subjects': 109448,
#  'status': 108307,
#  'assessed': 14910,
#  'masked': 69180,
#  ...}

# %%
len(vec.vocabulary_)
# Out:
# 124529

# %%
df.shape
# Out:
# (46985, 7)

# %%
abstract = 'In this paper we do computing. It is very quantum hybrid computing'

# %%
vec.transform([abstract]).todense().nonzero()
# Out:
# (array([0, 0, 0, 0], dtype=int64),
#  array([27906, 55573, 84515, 94614], dtype=int64))

# %%
vec.transform([abstract]).todense()[0,27906]
# Out:
# 2

# %%
vec.vocabulary_['computing']
# Out:
# 27906

# %%
X = vec.transform(df['Abstract'])

# %%
X.shape
# Out:
# (46985, 124529)

# %%
df.shape
# Out:
# (46985, 7)

# %% [markdown]
# # Building a classifier

# %% [markdown]
# **Important!!!** The vectorizer needs to be created on the training set, and then used on the testing.

# %%
import numpy as np

# %%
np.random.seed(123)

# %%
train_idxs = np.random.choice(df.index.values, size=int(df.shape[0]*7))

# %%
test_idxs = [ix for ix in df.index.values if ix not in train_idxs]

# %%
train_df = df.iloc[train_idxs, :]
test_df = df.iloc[test_idxs, :]

# %%
set(train_df['Domain'])
# Out:
# {'CS ', 'Civil ', 'ECE ', 'MAE ', 'Medical ', 'Psychology  ', 'biochemistry '}

# %%
set(test_df['Domain'])
# Out:
# {'CS ', 'Civil ', 'ECE ', 'MAE ', 'Medical ', 'Psychology  ', 'biochemistry '}

# %% [markdown]
# **Now we can fit the vectorizer on the train**

# %%
X_train = vec.fit_transform(train_df['Abstract']) # 
X_test = vec.transform(test_df['Abstract']) # Use the freshly fit vectorizer with transform only

# %% [markdown]
# **Also need to correctly encode the labels**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
y_train = le.fit_transform(train_df['Domain'])
y_test = le.transform(test_df['Domain'])

# %%
set(y_train)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
set(y_test)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %% [markdown]
# **Apply SVC:** SVC works well with less than 100k observations and can handle a high number of variables (hundreds of thousands).

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# C:\Users\HP\Anaconda3\envs\bern\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# Re-using the model / Use in production
pipe = Pipeline([('vec',CountVectorizer()), ('svm', SVC())])
pipe.fit(X_train, y_train)
dump.save(pipe, open('model.pkl', 'wb')) # save the model for persistance
# To call from API
# Load the pickled object
pipe = dump.load('model.pkl')
pipe.predict(['Here is my new abstract'])
